# %%
from random import seed

import pandas as pd
import numpy as np
import scipy.stats as ss
import random
import matplotlib.pyplot as plt
import time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from random import seed
#       2
# ----> 3 import pandas as pd
#       4 import numpy as np
#       5 import scipy.stats as ss
#       6 import random
#
# File ~/PycharmProjects/Lab4/.venv/lib/python3.12/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
#      58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
# ...

# %%
from ImprovedDataGen import Experiment

STD_CFG  ={ "ability_df": 5,
    "prep_mean": 4.3,
    "prep_sigma": 0.7,
    "quiz_sd": 2.2,
    "quiz_mean": 6,
    "final_mean": 18.3,
    "final_sd": 2.7}

TEST_STD_CFG  ={"ability_df": 5,
    "prep_mean": 4.15,
    "prep_sigma": 0.7,
    "quiz_sd": 2.2,
    "quiz_mean": 6.56,
    "final_mean": 19.2,
    "final_sd": 2.7}

exp = Experiment(9999999, STD_CFG, TEST_STD_CFG)

# %%
exp.control_data
# Out:
#                              id  second_quiz  final_grade   prep_time  \
# 0     robinsonmegan@example.com          5.0         21.0   29.142336
# 1          smaynard@example.com          4.0         17.0   29.269818
# 2         rgalloway@example.net          5.0         20.0  125.836475
# 3          amanda56@example.com         10.0         15.0    0.000000
# 4       ryanhoffman@example.org          4.0         20.0    0.000000
# ..                          ...          ...          ...         ...
# 263    adamsrichard@example.net          6.0         18.0   78.973626
# 264      moorenorma@example.com          7.0         21.0    0.000000
# 265          xjones@example.org          6.0         30.0  178.963357
# 266  bradleycollins@example.org          0.0         20.0   18.359609
# 267   warrenmichael@example.org          9.0         19.0    0.000000
#
#      SECRET!!!!
# 0      1.324394
# 1     -0.022956
# 2     -0.709782
# 3     -1.157319
# 4     -1.206488
# ..          ...
# ...

# %%
exp.test_data
# Out:
#                                id  second_quiz  final_grade   prep_time  \
# 0           njohnston@example.net          7.0         23.0   85.656286
# 1       christopher17@example.net          1.0         21.0   71.418463
# 2           richard18@example.com          2.0         22.0   68.634837
# 3            iedwards@example.com          8.0         21.0    0.000000
# 4        martinangela@example.com          9.0         18.0    0.000000
# ..                            ...          ...          ...         ...
# 245          vjohnson@example.org          8.0         22.0   39.386918
# 246      stuartdakota@example.com          7.0         18.0   10.044037
# 247  padillaelizabeth@example.net          7.0         27.0  153.547778
# 248    bradleynichols@example.net          8.0         28.0  186.212642
# 249   alexandertaylor@example.com          5.0         20.0    0.000000
#
#      SECRET!!!!
# 0     -0.450846
# 1      0.664778
# 2     -0.132632
# 3     -1.131948
# ...

# %%
exp.test_data.to_csv("test_data.csv")

# %%
exp.control_data.to_csv("control_data.csv")
